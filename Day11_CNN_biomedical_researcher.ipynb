# %% [markdown]
# Scenario Question
# # A biomedical researcher is designing a convolutional neural network (CNN) to analyze microscopic grayscale images of blood cells (64×64 pixels). She begins with a single convolutional layer defined as follows:
#
# Input: 64×64 grayscale images (1 channel)
# Convolutional Layer: 16 filters, each of size 5×5
# Stride: 1
# Padding: Same
# Activation Function: ReLU
# The goal of this layer is to extract local structural features such as cell boundaries and texture variations, which will later help in classifying whether the blood cells are healthy or show signs of abnormality.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Activation
import numpy as np

# Step 1: Create CNN model
model = Sequential()

# Step 2: Add Convolution Layer based on the scenario
model.add(Conv2D(
    filters=16,           # 16 filters
    kernel_size=(5,5),    # filter size 5x5
    strides=(1,1),        # stride 1
    padding='same',       # same padding
    activation='relu',    # ReLU activation
    input_shape=(64,64,1) # grayscale image
))

# Step 3: Display model architecture
model.summary()


# Step 4: Create a dummy blood cell image for testing
sample_image = np.random.rand(1,64,64,1)

# Step 5: Pass image through CNN layer
feature_maps = model.predict(sample_image)

# Step 6: Print output shape
print("Output Feature Map Shape:", feature_maps.shape)
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_1 (Conv2D)               │ (None, 64, 64, 16)     │           416 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 416 (1.62 KB)
#  Trainable params: 416 (1.62 KB)
#  Non-trainable params: 0 (0.00 B)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Output Feature Map Shape: (1, 64, 64, 16)
