# %%
#  Scenario: AI‑Powered Email Assistant
# You’re building an email drafting assistant for a corporate team.
# - When a user starts typing:
# “Artificial Intelligence will…”
# - The assistant uses GPT‑2 to auto‑complete the sentence with a coherent continuation.
# - Example output:
# “Artificial Intelligence will transform the way businesses interact with customers,
# enabling faster decisions and personalized experiences.”

from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

print(generator("Artificial Intelligence will", max_length=30))
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:104: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Passing `generation_config` together with generation-related arguments=({'max_length'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'Artificial Intelligence will be the key to unlocking the potential of artificial intelligence. The new technology, known as artificial intelligence, will be able to learn from people, but will not be able to analyze their behavior.\n\nSome experts believe that artificial intelligence will be used to control the economy. The technology will allow machines to manage their own lives and to make decisions based on their needs and desires.\n\nDr. Zbigniew Brzezinski, a professor of psychology at the University of Pennsylvania, noted in a recent interview, "The great thing about artificial intelligence is that it\'s not just a computer system. It\'s a whole system of human experiences, a whole system of human attitudes, and all that stuff. It\'s kind of like our understanding of what our world is about."\n\nThe future of intelligence\n\nThe future of artificial intelligence will be a very different future than what is currently being discussed. The AI is a highly automated intelligence that can be used in the production of certain products that are used in a specific business or society.\n\nThe U.S. government is currently working on a software program called DeepMind that is able to study the human brain and learn about the actions of people and other objects. Although the technology is being developed, the U.S'}]

# %%
#  Scenario: Game Storyline Generator
# You’re designing a fantasy role‑playing game and need quick ideas for quests and dialogue.
# - The developer types a prompt:
# “The hero enters the ancient forest and discovers…”
# - The GPT‑2 pipeline continues the story:
# “The hero enters the ancient forest and discovers a hidden village where the people whisper of
#  a cursed artifact buried beneath the old ruins.”

from transformers import pipeline
generator = pipeline("text-generation", model="gpt2")
print(generator("The hero enters the ancient forest and discovers", max_length=30))
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': "The hero enters the ancient forest and discovers a child's face and a hand which is wrapped around his arm. The child's body has been burned with fire and the child's body is now lying in the forest. The hero attempts to save the child from the flames, but is attacked by a dragon. The dragon sends a sword through the chest of the child and the child's heart explodes in a fiery explosion. The hero is then attacked by the dragon again. The dragon sends the chest of the child back out into the forest. The hero then falls in the river and falls into the fire. The dragon, with his spear, and the child are then caught by the hero. The hero saves the child and runs to the river where the dragon is. The dragon and the hero are finally caught and the hero leaves the battle.\n\nThe Dragon King fights the Dragon King in the Dragon Kingdom.\n\nChapter 7 – The Wind Dragon\n\nWhen the wind dragon is defeated, the hero is seen standing outside the castle. The hero goes to the castle and reveals that he has been attacked by a Wind Dragon, the Wind Dragon of the Great Forest and the Wind Dragon of the Great Sea of Water. The hero is attacked by the Wind Dragon and is taken by it. The Wind Dragon then attacks the hero"}]

# %%
# Scenario: Research Assistant for Academic Papers
# Imagine you’re building a tool for university researchers who analyze large collections of academic papers.
# - A researcher uploads a sentence:
# “Deep learning models are powerful”
# - Your system uses the BERT tokenizer to break the sentence into smaller units (tokens).

from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")

text = "Deep learning models are powerful"

tokens = tokenizer.tokenize(text)

print(tokens)
# Out:
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# ['deep', 'learning', 'models', 'are', 'powerful']

# %%
# 🏥 Scenario: Healthcare Chatbot for Patient Queries
# A hospital is developing a chatbot to help patients ask questions about their health.
# - A patient types:
# “Deep learning models are powerful” (or in practice, something like “I have chest pain and shortness of breath”).
# - The chatbot uses the BERT tokenizer to break the sentence into tokens:

from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
text = "Deep learning models are powerful"
tokens = tokenizer.tokenize(text)
print(tokens)
# Out:
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# ['deep', 'learning', 'models', 'are', 'powerful']

# %%
# Scenario: Exploring Creativity in AI Writing
# A university professor is running a workshop on creative writing with AI.
# - The professor gives students the prompt:
# “The future of Artificial Intelligence”
# - The system uses GPT‑2 to generate continuations of the sentence.
# To demonstrate how temperature affects creativity:
# - With temperature = 0.2 (low randomness), the output is more predictable and conservative, e.g.:
# “The future of Artificial Intelligence will bring advancements in healthcare, education, and business.”

from transformers import pipeline
generator = pipeline("text-generation", model="gpt2")
prompt = "The future of Artificial Intelligence"

print(generator(prompt, max_length=40, temperature=0.2))
print(generator(prompt, max_length=40, temperature=0.8))
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Passing `generation_config` together with generation-related arguments=({'temperature', 'max_length'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'The future of Artificial Intelligence is in the hands of the people.\n\nThe future of Artificial Intelligence is in the hands of the people.\n\nThe future of Artificial Intelligence is in the hands of the people.\n\nThe future of Artificial Intelligence is in the hands of the people.\n\nThe future of Artificial Intelligence is in the hands of the people.\n\nThe future of Artificial Intelligence is in the hands of the people.\n\nThe future of Artificial Intelligence is in the hands of the people.\n\nThe future of Artificial Intelligence is in the hands of the people.\n\nThe future of Artificial Intelligence is in the hands of the people.\n\nThe future of Artificial Intelligence is in the hands of the people.\n\nThe future of Artificial Intelligence is in the hands of the people.\n\nThe future of Artificial Intelligence is in the hands of the people.\n\nThe future of Artificial Intelligence is in the hands of the people.\n\nThe future of Artificial Intelligence is in the hands of the people.\n\nThe future of Artificial Intelligence is in the hands of the people.\n\nThe future of Artificial Intelligence is in the hands of the people.\n\nThe future of Artificial Intelligence is in the hands of the people.\n\nThe future of Artificial Intelligence is'}]
# [{'generated_text': "The future of Artificial Intelligence\n\nThe current state of artificial intelligence is the culmination of three decades of work at the National Institute of Standards and Technology. The goal is to design a computer that can handle problems using the basic principle of information processing. That's what's happening with AI. More than that, many machine learning algorithms and other complex techniques are also evolving.\n\nThe most recent iteration of a technique to learn about an object is a language called the LISA-based system for language learning.\n\nThe system is designed to be able to work in a computer science class with hundreds of students. But while it works at the same level as the classical language, it can't learn anything about a computer. The system uses a combination of different algorithms for different tasks.\n\nA system with five schools in California needs to learn about an object or a computer to be able to build a computer with that information. There are the three most recent generation of machine learning systems -- the LISA-based system, the LISA-based system for machine learning and the Neural Network, a system that can learn about an object or an image using the same information.\n\nThis system, known as the OpenAI-led Collaborative Process for Machine Learning, has been around for years. It was"}]

# %%
#  Scenario: Scriptwriting Assistant for Film Production
# A film studio is experimenting with AI to help writers brainstorm dialogue and plot ideas.
# - The writer provides the prompt:
# “The future of Artificial Intelligence”
# - The system generates two versions of the continuation:
# - Temperature = 0.2 (low randomness)
# Output is more predictable and formal, e.g.:
# “The future of Artificial Intelligence will improve industries, enhance productivity, and reshape education.”
# → This is useful for serious, factual narration in a documentary script.
# - Temperature = 0.8 (higher randomness)
# Output is more imaginative and varied, e.g.:
# “The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn.”
# → This is perfect for creative dialogue or speculative sci‑fi storytelling

from transformers import pipeline
generator = pipeline("text-generation", model="gpt2")
prompt = "The future of Artificial Intelligence"


print(generator(prompt, max_length=40, temperature=0.2))
print(generator(prompt, max_length=40, temperature=0.8))
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'The future of Artificial Intelligence is in the hands of the next generation of AI researchers.\n\n"We\'re going to see a lot of new ideas coming out of the field," said Dr. Michael D. Dolan, a professor of computer science at the University of California, Berkeley. "We\'re going to see a lot of new ideas coming out of the field."\n\nThe new research, published in the journal Nature Communications, is the result of a collaboration between the University of California, Berkeley and the University of California, Berkeley.\n\nThe research was led by Dr. Michael Dolan, a professor of computer science at the University of California, Berkeley.\n\n"We\'re going to see a lot of new ideas coming out of the field," said Dolan, who is also a professor of computer science at the University of California, Berkeley. "We\'re going to see a lot of new ideas coming out of the field."\n\nThe research was funded by the National Science Foundation, the National Science Foundation, the National Institutes of Health, the National Science Foundation, the National Science Foundation, the National Science Foundation, the National Science Foundation, the National Science Foundation, the National Science Foundation, the National Science Foundation, the National Science Foundation, the National Science Foundation, the National'}]
# [{'generated_text': 'The future of Artificial Intelligence (AI) is in full swing. According to a report on Artificial Intelligence Research Center at the University of California, Berkeley, this is because of the rise of artificial intelligence to become a real-world science.\n\nAn earlier version of this article incorrectly said that artificial intelligence researchers are focusing on real-world data. This is based on an earlier version of the article that stated that researchers were only focused on real-world data.'}]

# %%
# Scenario: AI‑Powered News Headline Generator
# A digital media company wants to help journalists brainstorm headlines and opening lines for articles.
# - The system asks the journalist to enter a prompt (e.g., “Enter a prompt: The future of Artificial Intelligence”).
# - The GPT‑2 model then generates a continuation of the text, up to 50 tokens.
# - Example output:
# “The future of Artificial Intelligence will reshape industries, redefine creativity, and challenge
#  our understanding of human potential.”

from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

prompt = input("Enter a prompt: ")

output = generator(prompt, max_length=50)

print(output[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Enter a prompt: future of artificial intelligence
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# future of artificial intelligence and artificial intelligence in general will be a long time coming. Perhaps the biggest obstacle is that AI is not yet ready to act with human control. (The problem of self-driving cars, which will allow cars to drive themselves, as well as cars that use human control, is still in the works).
#
# But when it comes to AI, there is still a lot of work to do. The next step is to identify what, if anything, is going wrong, and to make sure that a properly designed autonomous vehicle is able to cope with it.
#
# "One of the main things we have to do is to make sure that we have a vehicle that can do things as well as humans can," says Tod. "And that means knowing when it is safe to drive and when to stop."
#
# Tod has written three books on the subject, and recently spent the past two years working on the future of artificial intelligence in general. He has also written for the Guardian newspaper and the Financial Times, and has worked for Wired.com, a technology news site, and the New York Times. He is also a professor of Computer Science at Cambridge University in the UK.

# %%
# 🎓 Scenario: Student Brainstorming Tool for Essay Writing
# A college student is struggling to start their essay.
# - The system prompts them:
# “Enter a prompt:”
# - The student types:
# “The impact of technology on education”
# - The GPT‑2 model generates a continuation up to 50 tokens, for example:
# “The impact of technology on education has transformed classrooms, enabling online learning,
# personalized study plans, and global collaboration among students.”


# 🎓 Scenario: Student Brainstorming Tool for Essay Writing

# Step 1: Install required library
# !pip install transformers torch -q

# Step 2: Import libraries
from transformers import GPT2LMHeadModel, GPT2Tokenizer

# Step 3: Load GPT-2 model and tokenizer
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
model = GPT2LMHeadModel.from_pretrained("gpt2")

# Step 4: Take input from the user
prompt = input("Enter a prompt: ")

# Step 5: Convert text prompt into tokens
inputs = tokenizer.encode(prompt, return_tensors="pt")

# Step 6: Generate text continuation (up to 50 tokens)
outputs = model.generate(
    inputs,
    max_length=50,
    num_return_sequences=1,
    no_repeat_ngram_size=2,
    early_stopping=True
)

# Step 7: Decode and print the generated text
generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)

print("\nGenerated Essay Idea:\n")
print(generated_text)
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Enter a prompt: Online education is
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generated Essay Idea:
#
# Online education is  a very important part of our lives. We need to be able to learn from our peers and learn how to make a difference in our communities.
# I am not saying that we should be teaching our children to read, write

# %%
# Scenario: AI Model Evaluation in a Startup
# A startup is building an AI‑powered content assistant to help marketers draft product descriptions.
# - The team wants to compare two models: GPT‑2 (larger, more expressive) and DistilGPT‑2 (smaller, faster, distilled version).
# - They use the same prompt:
# “Artificial Intelligence will transform”
# - The system generates two outputs:
# - GPT‑2 Output
# Longer, more detailed continuation, e.g.:
# “Artificial Intelligence will transform industries by automating processes, enhancing creativity, and
# reshaping how humans interact with technology.”
# → Richer but slower to run.
# - DistilGPT‑2 Output


from transformers import pipeline

gpt2 = pipeline("text-generation", model="gpt2")
distilgpt2 = pipeline("text-generation", model="distilgpt2")

prompt = "Artificial Intelligence will transform"

print("GPT2:", gpt2(prompt, max_length=40))
print("DistilGPT2:", distilgpt2(prompt, max_length=40))
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# config.json:   0%|          | 0.00/762 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/353M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: distilgpt2
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# transformer.h.{0, 1, 2, 3, 4, 5}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# GPT2: [{'generated_text': 'Artificial Intelligence will transform the way we think about what it means to be a human being.\n\nThe answer to the question of how to use AI in the workplace comes from a recent report by the Pew Research Center that found that just 15 percent of Americans want to see AI improve their job performance. A large majority of Americans believe AI will change the way we think about work, but those same Americans may be more worried about the future of the human race.\n\n"As we move toward a new era of automation and automation of jobs, it will be important for our leaders to look to the future of humanity," said the Pew Research Center\'s Mark Harris, "to see how this innovation could change the way we think about work and the way we talk about how technology can help us get out of this mess."'}]
# DistilGPT2: [{'generated_text': 'Artificial Intelligence will transform the public into a more intelligent, social, economic and moral society.\n\n\n\n“The first step in a process which will be a complete and universal revolution will take place in the coming years as the world’s largest information technology companies are expected to bring a huge audience of people to the world’s most important industries.”\nThe new technology will revolutionize communication between the world as it becomes more and more widely available, as the technology becomes more and more widely available.'}]

# %%
# Scenario: Educational Tool for Classroom Learning
# A high school teacher is introducing students to AI‑powered writing assistants.
# - The teacher wants to show how different models produce different styles of text.
# - They use the same prompt:
# “Artificial Intelligence will transform”
# - The system generates two outputs:
# - GPT‑2 Output
# More elaborate continuation, e.g.:
# “Artificial Intelligence will transform the way societies function, influencing education, healthcare, and the future of human creativity.”
# → Great for showing students how AI can generate rich, detailed ideas.
# - DistilGPT‑2 Output
# Shorter, faster continuation, e.g.:
# “Artificial Intelligence will transform our daily lives.”
# → Useful for demonstrating concise summaries.


# 🎓 Scenario: Student Brainstorming Tool for Essay Writing

# Step 1: Install required library
# !pip install transformers torch -q

# Step 2: Import libraries
from transformers import GPT2LMHeadModel, GPT2Tokenizer

# Step 3: Load GPT-2 model and tokenizer
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
model = GPT2LMHeadModel.from_pretrained("gpt2")

# Step 4: Take input from the user
prompt = input("Enter a prompt: ")

# Step 5: Convert text prompt into tokens
inputs = tokenizer.encode(prompt, return_tensors="pt")

# Step 6: Generate text continuation (up to 50 tokens)
outputs = model.generate(
    inputs,
    max_length=50,
    num_return_sequences=1,
    no_repeat_ngram_size=2,
    early_stopping=True
)

# Step 7: Decode and print the generated text
generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)

print("\nGenerated Essay Idea:\n")
print(generated_text)
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Enter a prompt: Artificial Intelligence will transform
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generated Essay Idea:
#
# Artificial Intelligence will transform the way we think about the world. It will change how we live, work, and play.
#
# The future of AI is not a question of whether we will be able to solve the problems of the future, but
