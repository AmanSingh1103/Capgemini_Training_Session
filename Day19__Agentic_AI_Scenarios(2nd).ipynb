# %% [markdown]
# # **Agentic AI**

# %% [markdown]
# # Scenario: Smart Shopping Assistant 🛒
#
# You say to your students:
# “Imagine you are planning a party and you tell your assistant:
# ‘Find me the best chocolate cake under ₹500.’
# Now instead of just replying with text, your assistant actually thinks, checks different bakery websites, compares prices, and then gives you the final decision.”

# %%
# Smart Shopping Assistant (Agentic AI Simulation)

# Step 1: Available cakes (data collected from "websites")
cakes = [
    {"name": "Chocolate Truffle", "price": 480, "rating": 4.5, "delivery_time": 30},
    {"name": "Dark Chocolate Cake", "price": 520, "rating": 4.7, "delivery_time": 25},
    {"name": "Chocolate Cream Cake", "price": 450, "rating": 4.2, "delivery_time": 40},
    {"name": "Choco Lava Cake", "price": 400, "rating": 4.0, "delivery_time": 35}
]

# %%
# Step 2: User goal
budget = 500

print("🎯 Goal: Find best chocolate cake under ₹500\n")

# Step 3: Filter cakes within budget (Perception)
valid_cakes = []
for cake in cakes:
    if cake["price"] <= budget:
        valid_cakes.append(cake)
# Out:
# 🎯 Goal: Find best chocolate cake under ₹500

# %%
# Step 4: Reasoning (compare cakes based on rating and delivery)
# Sort by highest rating, then fastest delivery
valid_cakes.sort(key=lambda x: (-x["rating"], x["delivery_time"]))

# Step 5: Decision
best_cake = valid_cakes[0]

# Step 6: Action (final output)
print("✅ Best Cake Found:")
print(f"Name: {best_cake['name']}")
print(f"Price: ₹{best_cake['price']}")
print(f"Rating: {best_cake['rating']} ⭐")
print(f"Delivery Time: {best_cake['delivery_time']} mins")
# Out:
# ✅ Best Cake Found:
# Name: Chocolate Truffle
# Price: ₹480
# Rating: 4.5 ⭐
# Delivery Time: 30 mins

# %% [markdown]
# # Scenario: The University’s AI Plagiarism Agent
# Imagine a university has deployed an AI-powered plagiarism detection agent named PlagiarismLLM.
# Its job is to monitor student essay submissions in real time and decide whether they are original or potentially plagiarized.
#
#
# Step 1: Thinking (Reasoning)
# Whenever an essay is submitted, PlagiarismLLM first analyzes the text:
# - Example: “Essay contains large verbatim passages from online sources”
# - PlagiarismLLM thinks: “Analyzing essay: multiple verbatim passages detected.”
#
# Step 2: Planning (Choosing an Action)
# Based on the thought, PlagiarismLLM decides which tool to use:
# - If the essay has long verbatim matches or suspicious similarity scores, it plans to flag as potential plagiarism.
# - Otherwise, it plans to mark as original work.
#
# Step 3: Acting (Running Tools)
# PlagiarismLLM hands over the decision to PlagiarismTools, which executes the action:
# - flag_plagiarism → returns “Potential Plagiarism Detected”
# - mark_original → returns “Original Work”
#
# Step 4: Answering (Final Decision)
# Once a clear classification is reached, PlagiarismLLM announces the decision:
# - “Decision: Potential Plagiarism Detected”
# - “Decision: Original Work”

# %%
# AI Plagiarism Agent Simulation

# -------------------------------
# Step 0: Sample Essays (input)
# -------------------------------
essays = [
    "This essay is completely original and written by the student.",
    "This essay contains copied content from Wikipedia and other online sources.",
    "The student has written most parts but some sentences are copied from internet."
]

# -------------------------------
# Step 1: Thinking (Reasoning)
# -------------------------------
def analyze_essay(essay):
    print("\n🧠 Thinking...")

    # Simple rule-based detection (simulation)
    suspicious_keywords = ["copied", "Wikipedia", "online sources", "internet"]

    score = 0
    for word in suspicious_keywords:
        if word.lower() in essay.lower():
            score += 1

    print(f"Analysis Score: {score}")
    return score

# -------------------------------
# Step 2: Planning (Decision)
# -------------------------------
def plan_action(score):
    print("📋 Planning...")

    if score >= 2:
        return "flag_plagiarism"
    else:
        return "mark_original"

# -------------------------------
# Step 3: Acting (Tool Execution)
# -------------------------------
def plagiarism_tools(action):
    print("🛠️ Acting...")

    if action == "flag_plagiarism":
        return "Potential Plagiarism Detected"
    else:
        return "Original Work"

# -------------------------------
# Step 4: Final Answer
# -------------------------------
def plagiarism_agent(essay):
    print("\n📄 New Essay Submitted:")
    print(essay)

    # Think
    score = analyze_essay(essay)

    # Plan
    action = plan_action(score)

    # Act
    result = plagiarism_tools(action)

    # Answer
    print("🎯 Final Decision:", result)

# -------------------------------
# Run Agent on all essays
# -------------------------------
for e in essays:
    plagiarism_agent(e)
# Out:
# 📄 New Essay Submitted:
# This essay is completely original and written by the student.
#
# 🧠 Thinking...
# Analysis Score: 0
# 📋 Planning...
# 🛠️ Acting...
# 🎯 Final Decision: Original Work
#
# 📄 New Essay Submitted:
# This essay contains copied content from Wikipedia and other online sources.
#
# 🧠 Thinking...
# Analysis Score: 3
# 📋 Planning...
# 🛠️ Acting...
# 🎯 Final Decision: Potential Plagiarism Detected
#
# 📄 New Essay Submitted:
# The student has written most parts but some sentences are copied from internet.
#
# 🧠 Thinking...
# Analysis Score: 2
# 📋 Planning...
# 🛠️ Acting...
# 🎯 Final Decision: Potential Plagiarism Detected

# %% [markdown]
# ## Scenario

# %%
import requests

API_TOKEN = "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"
MODEL_ID = "meta-llama/Meta-Llama-3-8B-Instruct"

API_URL = "https://router.huggingface.co/v1/chat/completions"

headers = {
    "Authorization": f"Bearer {API_TOKEN}",
    "Content-Type": "application/json"
}

def query_llm(prompt: str):
    payload = {
        "model": MODEL_ID,
        "messages": [
            {"role": "user", "content": prompt}
        ],
        "max_tokens": 200
    }

    response = requests.post(API_URL, headers=headers, json=payload)
    data = response.json()

    if "choices" in data:
        return data["choices"][0]["message"]["content"]
    else:
        return str(data)


def flag_suspicious(transaction):
    return "Suspicious Transaction"


def mark_normal(transaction):
    return "Normal Transaction"


def fraud_agent(transaction: str):
    thought = query_llm(f"Analyze this transaction: {transaction}")
    print("LLM Thought:", thought)

    if "overseas" in transaction.lower() or "multiple deposits" in transaction.lower():
        action = flag_suspicious
    else:
        action = mark_normal

    result = action(transaction)

    final_answer = query_llm(f"Decision: {result}")
    return final_answer


print(fraud_agent("Payment to overseas account"))
# Out:
# LLM Thought: **Transaction Analysis: Payment to Overseas Account**
#
# **Transaction Details:**
#
# - **Type:** International Wire Transfer
# - **Currency:** USD (United States Dollar)
# - **Beneficiary Account:** Overseas bank account (Country: UK, Bank: Barclays)
# - **Beneficiary Name:** John Doe
# - **Amount:** $10,000
# - **Transfer Method:** Online banking platform
# - **Transfer Date:** 22nd February 2023
# - **Transfer Time:** 14:30 GMT
# - **Transaction Fee:** $30 (bank transfer fee)
#
# **Analysis:**
#
# 1. **Legitimacy:** The transaction appears to be legitimate, as it is a payment to a specific overseas account belonging to an individual. The payment amount is significant, but not unusually large for a business or personal transaction.
#
# 2. **Risk Assessment:** The risk associated with this transaction is moderate. International wire transfers can be vulnerable to money laundering, terrorist financing, and other illicit activities. However
# **Suspicious Transaction Decision**
#
# **Transaction Details:**
#
# * Date: 2023-02-20
# * Time: 14:30:00
# * Amount: $10,000
# * Originating Account: 1234567890
# * Destination Account: 9876543210
# * Transaction Type: Wire Transfer
#
# **Red Flags:**
#
# 1. **Large Transaction**: The transaction amount is significantly higher than the average daily transaction amount for the originating account.
# 2. **Unusual Pattern**: This is the first transaction between these two accounts, and there is no prior history of transactions between them.
# 3. **High-Risk Destination**: The destination account is located in a country with a high risk of money laundering and terrorist financing.
#
# **Analysis:**
#
# Based on the transaction details and red flags, this transaction appears to be suspicious and warrants further investigation. The large transaction amount and unusual pattern between the two accounts raise concerns about potential money laundering or terrorist financing activities.
#
# **Recommendations

# %% [markdown]
# ## 🏥 Scenario: The Hospital’s AI Appointment Agent
# Imagine a hospital has deployed an AI-powered agent named MediLLM.
# Its job is to monitor patient appointment requests and decide whether the requested slot is available or needs rescheduling.
#
# Step 1 — Thinking (Reasoning)
# Whenever a patient request comes in, MediLLM first analyzes the details:
# - Example: “Request for Dr. Sharma at 10 AM tomorrow”
# - MediLLM thinks: “Analyzing appointment request: Dr. Sharma, 10 AM tomorrow.”
#
# Step 2 — Planning (Choosing an Action)
# Based on the thought, MediLLM decides which tool to use:
# - If the requested slot is free, it plans to confirm appointment.
# - If the slot is already booked, it plans to suggest rescheduling.
#
# Step 3 — Acting (Running Tools)
# MediLLM hands over the decision to AppointmentTools, which executes the action:
# - confirm_slot → returns “Appointment Confirmed”
# - suggest_reschedule → returns “Slot Unavailable, Please Reschedule”
#
# Step 4 — Answering (Final Decision)
# Once a clear classification is reached, MediLLM announces the decision:
# - “Decision: Appointment Confirmed”
# - “Decision: Slot Unavailable, Please Reschedule”

# %%
import requests

# 🔐 Token (replace if needed)
API_TOKEN = "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"
MODEL_ID = "meta-llama/Meta-Llama-3-8B-Instruct"

API_URL = "https://router.huggingface.co/v1/chat/completions"

headers = {
    "Authorization": f"Bearer {API_TOKEN}",
    "Content-Type": "application/json"
}

# 🧠 LLM function
def query_llm(prompt: str):
    payload = {
        "model": MODEL_ID,
        "messages": [
            {"role": "user", "content": prompt}
        ],
        "max_tokens": 200
    }

    response = requests.post(API_URL, headers=headers, json=payload)
    data = response.json()

    if "choices" in data:
        return data["choices"][0]["message"]["content"]
    else:
        return str(data)


# 🛠️ Tools
def confirm_slot(request):
    return "Appointment Confirmed"

def suggest_reschedule(request):
    return "Slot Unavailable, Please Reschedule"


# 🤖 MediLLM Agent
def medi_agent(appointment_request: str):

    # Step 1: Thinking
    thought = query_llm(f"Analyze this appointment request: {appointment_request}")
    print("LLM Thought:", thought)

    # Step 2: Planning
    if "10 am" in appointment_request.lower() or "busy" in appointment_request.lower():
        action = suggest_reschedule
    else:
        action = confirm_slot

    # Step 3: Acting
    result = action(appointment_request)

    # Step 4: Final Answer
    final_answer = query_llm(f"Explain this decision: {result}")
    return final_answer


# 🚀 TEST
print(medi_agent("Request for Dr. Sharma at 10 AM tomorrow"))
print(medi_agent("Request for Dr. Sharma at 2 PM tomorrow"))
# Out:
# LLM Thought: Based on the given information, here's an analysis of the appointment request:
#
# 1. **Identity of the recipient:** The appointment is requested for Dr. Sharma, implying that Dr. Sharma is a medical professional or a specialist.
# 2. **Time of the appointment:** The requested time of the appointment is 10 AM tomorrow. This suggests that the appointment is for the next day.
# 3. **Lack of specific details:** The request does not mention the reason for the appointment, the duration of the visit, or the preferred method of communication (e.g., phone, email, or in-person consultation).
# 4. **Uncertainty about availability:** Since the request is made at an unspecified time, it's unclear whether Dr. Sharma has already reviewed his schedule and is available at 10 AM tomorrow.
# 5. **Assumptions and expectations:** The person making the request assumes that Dr. Sharma will be available at the requested time and that the appointment will be scheduled accordingly. However, it's essential
# This decision, "Slot Unavailable, Please Reschedule," is a common response given to individuals when they attempt to book an appointment or reserve a specific time slot, but it is no longer available. Here are some possible reasons behind this decision:
#
# 1. **Overbooking**: The service provider might have overestimated the number of available slots, leading to a shortage of time slots for customers.
# 2. **Last-minute cancellations**: If a scheduled appointment is cancelled at the last minute, the slot may become available, but it may be too late for other customers to book it.
# 3. **Unexpected demand**: A sudden surge in demand for the service or product may cause a shortage of available slots, making it difficult to accommodate all customers.
# 4. **Maintenance or technical issues**: Equipment failure, software glitches, or other technical issues might lead to the unavailability of a particular slot.
# 5. **Staffing constraints**: Inadequate staffing or scheduling issues may result in a shortage of available slots,
# LLM Thought: Here's an analysis of the appointment request:
#
# **Key Information:**
#
# 1. **Doctor's Name:** Dr. Sharma
# 2. **Appointment Time:** 2 PM
# 3. **Date:** Tomorrow (assuming the speaker has already mentioned the current date)
#
# **Analysis:**
#
# 1. **Specificity:** The appointment request provides specific details about the doctor's name and the desired appointment time, which is helpful for scheduling purposes.
# 2. **Lack of Context:** There is no additional context provided, such as the patient's name, reason for the appointment, or any specific requirements or requests.
# 3. **Assumed Information:** The speaker assumes that the current date has already been established, which may not be the case if the conversation started from scratch.
# 4. **Implication:** The request implies that the speaker is expecting Dr. Sharma to be available at the specified time, without confirming the doctor's schedule or availability.
#
# **Suggestions:**
#
# 1. **Confirm the Date:** To avoid confusion
# Without more context, it's difficult to provide a specific explanation for the "Appointment Confirmed" decision.
#
# However, I can provide some general information on what might lead to such a decision in various scenarios:
#
# 1. **Job or Staffing**: In a professional setting, an "Appointment Confirmed" decision might indicate that a job offer has been accepted by a candidate, and their appointment as an employee is now confirmed.
# 2. **Meeting or Event**: In a personal or social context, "Appointment Confirmed" might mean that a meeting or event has been scheduled and confirmed, and the details are now set in stone.
# 3. **Booking or Reservation**: In a service industry, "Appointment Confirmed" could indicate that a customer's booking or reservation has been confirmed, and they can expect to receive a service at the scheduled time.
# 4. **Medical or Healthcare**: In a medical or healthcare context, "Appointment Confirmed" might mean that a patient's appointment with a doctor or healthcare professional
