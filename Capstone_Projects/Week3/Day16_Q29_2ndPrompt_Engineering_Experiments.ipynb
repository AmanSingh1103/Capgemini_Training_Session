# %%
# Install Groq library
# !pip install -q groq

# Import libraries
from groq import Groq
import os

# Add your Groq API key
os.environ["GROQ_API_KEY"] = "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"

# Initialize client
client = Groq(api_key=os.environ.get("GROQ_API_KEY"))

# Sample article
article = """
Artificial Intelligence (AI) is transforming many industries including healthcare,
finance, education, and transportation. Machine learning algorithms can analyze
large datasets to identify patterns and make predictions. AI-powered systems are
used for disease diagnosis, fraud detection, personalized learning, and autonomous
vehicles.

Despite its benefits, AI also raises ethical concerns such as data privacy,
algorithmic bias, and job displacement. Researchers and policymakers are working
to create responsible AI systems that are transparent, fair, and accountable.

In the future, AI is expected to become even more integrated into everyday life,
helping humans solve complex problems and improve decision-making.
"""

# Experiment 1
prompt1 = f"""
Summarize the following article in 5 bullet points.

Article:
{article}
"""

response1 = client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=[{"role": "user", "content": prompt1}],
    temperature=0.7,
    max_tokens=300
)

print("Experiment 1 Output:\n")
print(response1.choices[0].message.content)

# Experiment 2
prompt2 = f"""
You are an AI research assistant.

1. Summarize the article in 3 sentences
2. List two risks of AI
3. Suggest one future application

Article:
{article}
"""

response2 = client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=[{"role": "user", "content": prompt2}],
    temperature=0.6,
    max_tokens=300
)

print("\nExperiment 2 Output:\n")
print(response2.choices[0].message.content)

# Experiment 3
prompt3 = f"""
Explain the article to a beginner student in simple language in about 100 words.

Article:
{article}
"""

response3 = client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=[{"role": "user", "content": prompt3}],
    temperature=0.6,
    max_tokens=200
)

print("\nExperiment 3 Output:\n")
print(response3.choices[0].message.content)
# Out:
# Experiment 1 Output:
#
# Here are 5 bullet points summarizing the article:
#
# • Artificial Intelligence (AI) is transforming various industries, including healthcare, finance, education, and transportation, by analyzing large datasets and making predictions.
#
# • Machine learning algorithms in AI are used in areas such as disease diagnosis, fraud detection, personalized learning, and autonomous vehicles, improving efficiency and outcomes.
#
# • Despite its benefits, AI raises ethical concerns, including data privacy, algorithmic bias, and job displacement, which require attention from researchers and policymakers.
#
# • Efforts are being made to create responsible AI systems that are transparent, fair, and accountable to mitigate these ethical concerns.
#
# • As AI becomes increasingly integrated into everyday life, it is expected to help humans solve complex problems and improve decision-making in the future.
#
# Experiment 2 Output:
#
# ...

# %% [markdown]
# Zero Shot Output

# %%
zero_shot_prompt = f"""
Summarize the following article in 5 bullet points.

Article:
{article}
"""

response = client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=[{"role":"user","content":zero_shot_prompt}],
    temperature=0.6,
    max_tokens=250
)

print("ZERO SHOT OUTPUT:\n")
print(response.choices[0].message.content)
# Out:
# ZERO SHOT OUTPUT:
#
# Here are 5 bullet points summarizing the article:
#
# • Artificial Intelligence (AI) is transforming various industries, including healthcare, finance, education, and transportation, through machine learning algorithms that analyze large datasets.
#
# • AI-powered systems are being used for tasks such as disease diagnosis, fraud detection, personalized learning, and autonomous vehicles, offering numerous benefits.
#
# • However, AI also raises ethical concerns, including data privacy, algorithmic bias, and job displacement, which researchers and policymakers are working to address.
#
# • Efforts are being made to create responsible AI systems that are transparent, fair, and accountable, ensuring that the technology is used in a beneficial and trustworthy manner.
#
# • In the future, AI is expected to become increasingly integrated into everyday life, helping humans solve complex problems and improve decision-making capabilities.

# %% [markdown]
# Few Shot Prompt

# %%
few_shot_prompt = f"""
Example 1
Article: Solar energy is becoming popular because it is renewable and reduces pollution.
Summary:
• Solar energy is renewable
• It reduces environmental pollution
• Adoption of solar power is increasing

Example 2
Article: Online education enables students to learn remotely using internet technologies.
Summary:
• Online learning allows remote education
• Technology enables virtual classrooms
• Students can access courses globally

Now summarize the following article in 5 bullet points.

Article:
{article}
"""

response = client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=[{"role":"user","content":few_shot_prompt}],
    temperature=0.6,
    max_tokens=250
)

print("FEW SHOT OUTPUT:\n")
print(response.choices[0].message.content)
# Out:
# FEW SHOT OUTPUT:
#
# Here's a summary of the article in 5 bullet points:
#
# • Artificial Intelligence (AI) is transforming various industries, including healthcare, finance, education, and transportation.
# • AI-powered systems use machine learning algorithms to analyze large datasets, identify patterns, and make predictions.
# • AI has multiple applications, such as disease diagnosis, fraud detection, personalized learning, and autonomous vehicles.
# • However, AI also raises concerns about data privacy, algorithmic bias, and job displacement, requiring responsible AI systems.
# • In the future, AI is expected to become increasingly integrated into everyday life, helping humans solve complex problems and improve decision-making.

# %% [markdown]
# Chain of Thoughts

# %%
cot_prompt = f"""
Analyze the article step by step.

Step 1: Identify the main topic
Step 2: Extract the key ideas
Step 3: Generate a concise summary

Article:
{article}
"""

response = client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=[{"role":"user","content":cot_prompt}],
    temperature=0.6,
    max_tokens=300
)

print("CHAIN OF THOUGHT OUTPUT:\n")
print(response.choices[0].message.content)
# Out:
# CHAIN OF THOUGHT OUTPUT:
#
# Here's the step-by-step analysis:
#
# **Step 1: Identify the main topic**
#
# The main topic of the article is the impact and future of Artificial Intelligence (AI) on various industries and society.
#
# **Step 2: Extract the key ideas**
#
# The key ideas in the article are:
#
# 1. AI is transforming various industries, including healthcare, finance, education, and transportation, through machine learning algorithms.
# 2. AI has benefits such as disease diagnosis, fraud detection, personalized learning, and autonomous vehicles.
# 3. AI raises ethical concerns, including data privacy, algorithmic bias, and job displacement.
# 4. Researchers and policymakers are working to create responsible AI systems that are transparent, fair, and accountable.
# 5. AI is expected to become even more integrated into everyday life in the future, helping humans solve complex problems and improve decision-making.
#
# **Step 3: Generate a concise summary**
#
# ...

# %% [markdown]
# Prompt Optimization

# %%
optimized_prompt = """
You are a professional business analyst.

Analyze the article and produce an executive summary with:

• 3 Key Insights
• 1 Actionable Takeaway
• Maintain a professional tone

Article:
"""

article1 = """
Remote work has increased globally after the pandemic.
Companies discovered that employees can remain productive while working from home.
However, challenges such as communication gaps and employee isolation remain.
Organizations are investing in collaboration tools and hybrid work models.
"""

response = client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=[{"role":"user","content": optimized_prompt + article1}],
    temperature=0.6
)

print("ARTICLE 1 OUTPUT:\n")
print(response.choices[0].message.content)
# Out:
# ARTICLE 1 OUTPUT:
#
# **Executive Summary**
#
# **Global Shift to Remote Work: Key Insights and Actionable Takeaways**
#
# The COVID-19 pandemic has accelerated the shift to remote work globally, with companies discovering that employees can remain productive while working from home. However, challenges persist, and organizations are investing in collaboration tools and hybrid work models to mitigate these issues. As a business analyst, I have extracted the following key insights and actionable takeaway:
#
# **3 Key Insights:**
#
# 1. **Productivity Remains High in Remote Work Settings**: The pandemic has demonstrated that employees can maintain high levels of productivity while working from home, challenging traditional notions of office-based work.
# 2. **Communication Gaps and Isolation Remain Challenges**: Despite the benefits of remote work, communication gaps and employee isolation continue to be significant challenges for organizations, requiring strategic solutions.
# ...

# %%
article2 = """
Electric vehicles are gaining popularity as governments encourage sustainable
transportation. Advances in battery technology are increasing driving range
and reducing charging times.
Automobile companies are heavily investing in EV development.
"""
response = client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=[{"role":"user","content": optimized_prompt + article2}],
    temperature=0.6
)

print("ARTICLE 2 OUTPUT:\n")
print(response.choices[0].message.content)
# Out:
# ARTICLE 2 OUTPUT:
#
# **Executive Summary: Electric Vehicle Market Trends**
#
# As governments worldwide emphasize sustainable transportation, the electric vehicle (EV) market is experiencing significant growth. Our analysis yields valuable insights into the current market landscape and its implications for stakeholders.
#
# **Key Insights:**
#
# 1. **Government Incentives Drive Market Growth**: Governments are playing a crucial role in promoting the adoption of sustainable transportation by incentivizing the purchase of electric vehicles. This is likely to continue, driving demand for EVs and influencing market trends.
# 2. **Advancements in Battery Technology**: Continuous improvements in battery technology are extending driving ranges and reducing charging times, making EVs more appealing to consumers. This trend is expected to continue, further enhancing the competitiveness of EVs.
# ...

# %%
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")

paragraph = """
Artificial intelligence is transforming industries and enabling
machines to learn from data and improve decision making.
"""

tokens = tokenizer.tokenize(paragraph)
token_ids = tokenizer.encode(paragraph)

print("TOKENS:\n")
print(tokens)

print("\nTOTAL TOKENS:")
print(len(tokens))
# Out:
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# TOKENS:
#
# ['artificial', 'intelligence', 'is', 'transforming', 'industries', 'and', 'enabling', 'machines', 'to', 'learn', 'from', 'data', 'and', 'improve', 'decision', 'making', '.']
#
# TOTAL TOKENS:
# 17

# %% [markdown]
# **Building MINI AI Tool**

# %%
def ai_summary_tool(text):

    prompt = f"""
    Analyze the following article and provide:

    1. Short Summary
    2. Key Insights (3 bullet points)
    3. One Actionable Recommendation

    Article:
    {text}
    """

    response = client.chat.completions.create(
        model="llama-3.1-8b-instant",
        messages=[{"role":"user","content":prompt}],
        temperature=0.6,
        max_tokens=300
    )

    return response.choices[0].message.content
input_article = """
  AI-powered healthcare systems can detect diseases earlier and
  support doctors with faster diagnosis. Hospitals are adopting
  machine learning tools for medical imaging and patient monitoring.
  """

result = ai_summary_tool(input_article)

print("AI TOOL OUTPUT:\n")
print(result)
# Out:
# AI TOOL OUTPUT:
#
# **1. Short Summary:**
# The article highlights the adoption of AI-powered healthcare systems in hospitals, which can lead to earlier disease detection and faster diagnosis.
#
# **2. Key Insights:**
# * AI-powered healthcare systems are being adopted by hospitals to improve diagnosis efficiency.
# * These systems can detect diseases earlier than traditional methods.
# * Machine learning tools are being used for medical imaging and patient monitoring.
#
# **3. One Actionable Recommendation:**
# Hospitals should invest in AI-powered healthcare systems and train their medical staff on the use of machine learning tools for medical imaging and patient monitoring to stay competitive and improve patient outcomes.
