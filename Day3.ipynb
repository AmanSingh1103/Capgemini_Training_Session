# %% [markdown]
# # **Matplotlib**

# %%
import matplotlib.pyplot as plt

months = ["Jan","Feb","Mar","Apr"]
sales = [10000,12000,15000,13000]

plt.plot(months , sales)
plt.title("Monthly Sales Trends")
plt.xlabel("Months")
plt.ylabel("Sales")
plt.show()

# %% [markdown]
# Here's a different context scenario question using your line chart idea, but instead of Let's make it
#
# about student attendance:
#
# Scenario Question
#
# college is tracking student attendance across the first four months of the semester:
#
# January: 85 students present on average
#
# February: 90 students
#
# March: 95 students
#
# -April: 88 students
#
# The academic coordinator wants to visualize the attendance trend to see whether students are attending classes more regularly or
#
# if there are fluctuations.
#
# You are asked to:
#
# Plot a line chart showing the monthly attendance trend.
#
# Label the axes and add a title to make the chart clear.
#
# Interpret the chart:
#
# Which month had the highest attendance?
#
# Did attendance steadily increase, or were there ups and downs?
#
# What might explain the dip in April?

# %%
import matplotlib.pyplot as plt
months = ["January", "February", "March", "April"]
attendance = [85, 90, 95, 88]

plt.figure()
plt.plot(months, attendance, marker='o')

plt.xlabel("Months")
plt.ylabel("Average Number of Students Present")
plt.title("Monthly Student Attendance Trend")

plt.grid(True)

plt.show()

# %%
regions = ["North","South","East","West"]
revenue = [200000,150000,180000,220000]

plt.bar(regions, revenue)
plt.title("Revenue by Region")
plt.show()

# %% [markdown]
# Scenario Question
#
# A university library tracked the number of books checked out from four sections during the last ster:
#
# North Wing: 2,000 books
#
# South Wing: 1,500 books
#
# East Wing: 1,800 books
#
# West Wing: 2,200 books
#
# The librarian wants to compare which section had the highest activity and which section had the lowest.
#
# You are asked to:
#
# Plot a bar chart showing the number of books checked out by section.
#
# Add a title and axis labels to make the chart clear.
#
# Interpret the chart:
#
# which section had the highest checkouts?
#
# Which section had the lowest?
#
# What insights could the librarian use to improve resource allocation?

# %%
import matplotlib.pyplot as plt

sections = ["North Wing", "South Wing", "East Wing", "West Wing"]
books_checked_out = [2000, 1500, 1800, 2200]

plt.figure()
plt.bar(sections, books_checked_out,color=["cyan","grey","black","cyan"])


plt.xlabel("Library Sections")
plt.ylabel("Number of Books Checked Out")
plt.title("Library Book Checkouts by Section (Last Semester)")


plt.show()

# %% [markdown]
# # Histogram
#
# # Here's how you can turn your salary distribution histogram into a scenario-style question for students:
#
# # Scenario Question
#
# # A company surveyed the salaries of 1,000 employees. The average salary was around $50,000, with most emp]
#
# #within a spread of about $10,000.
#
# # The HR department wants to visualize the distribution of salaries to understand pay structure and identit
#
# #clustered around the average or spread out widely.
#
# #You are asked to:
#
# # Plot a histogram showing the salary distribution.
#
# #Add a title to make the chart clear.
#
# # Interpret the chart:

# %% [markdown]
# <!-- # Histogram
#
# # Here's how you can turn your salary distribution histogram into a scenario-style question for students:
#
# # Scenario Question
#
# # A company surveyed the salaries of 1,000 employees. The average salary was around $50,000, with most emp
#
# #within a spread of about $10,000.
#
# # The HR department wants to visualize the distribution of salaries to understand pay structure and identit
#
# #clustered around the average or spread out widely.
#
# #You are asked to:
#
# # Plot a histogram showing the salary distribution.
#
# #Add a title to make the chart clear.
#
# # Interpret the chart: -->

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate sample salary data (1000 employees)
np.random.seed(42)
salaries = np.random.normal(50000, 10000, 1000)

# Create histogram
plt.figure()
plt.hist(salaries, bins=30)

# Title and labels
plt.title("Distribution of Employee Salaries")
plt.xlabel("Salary ($)")
plt.ylabel("Number of Employees")

plt.show()

# %% [markdown]
# # 📘 Scenario Question
# # A professor recorded the exam scores of 1,000 students in a statistics course. The average
# # score was around 75 marks, with most
# # students scoring within a spread of about 10 marks.
# # The professor wants to visualize the distribution of exam scores to understand how students
# #  performed overall and
# #  whether the scores follow a normal pattern.
# # You are asked to:
# # - Plot a histogram showing the distribution of exam scores.
# # - Add a title and axis labels to make the chart clear.
# # - Interpret the chart:
# # - What does the shape of the distribution suggest about student performance?
# # - Are most students clustered around the average, or is there wide variation?
# # - How could the professor use this information to adjust teaching methods?

# %%
import matplotlib.pyplot as plt
import numpy as np

scores = np.random.normal(75, 10, 1000)

plt.figure()
plt.hist(scores, bins=20)

plt.title("Distribution of Exam Scores")
plt.xlabel("Marks")
plt.ylabel("Number of Students")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(42)
ad_spend = np.random.uniform(2000, 18000, 50)
sales_revenue = ad_spend * 2.5 + np.random.normal(0, 5000, 50)

print("=" * 70)
print("ADVERTISING SPEND VS SALES REVENUE ANALYSIS")
print("=" * 70)
print()

print("Dataset Statistics:")
print(f"Total Campaigns: {len(ad_spend)}")
print(f"Ad Spend Range: ${np.min(ad_spend):.2f} - ${np.max(ad_spend):.2f}")
print(f"Average Ad Spend: ${np.mean(ad_spend):.2f}")
print(f"Sales Revenue Range: ${np.min(sales_revenue):.2f} - ${np.max(sales_revenue):.2f}")
print(f"Average Sales Revenue: ${np.mean(sales_revenue):.2f}")
print()

correlation = np.corrcoef(ad_spend, sales_revenue)[0, 1]
print(f"Correlation Coefficient: {correlation:.3f}")
print()

z = np.polyfit(ad_spend, sales_revenue, 1)
p = np.poly1d(z)
trend_line = p(ad_spend)

plt.figure(figsize=(12, 7))
plt.scatter(ad_spend, sales_revenue, color='#3498db', s=100, alpha=0.6, edgecolors='black', label='Campaign Data')
plt.plot(sorted(ad_spend), p(sorted(ad_spend)), color='red', linewidth=2, linestyle='--', label=f'Trend Line (y = {z[0]:.2f}x + {z[1]:.2f})')
plt.xlabel('Advertising Spend ($)', fontsize=12)
plt.ylabel('Sales Revenue ($)', fontsize=12)
plt.title('Relationship Between Advertising Spend and Sales Revenue', fontsize=14, fontweight='bold')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig('ad_spend_sales_scatter.png', dpi=300, bbox_inches='tight')
plt.show()

print("=" * 70)
print("TREND LINE ANALYSIS")
print("=" * 70)
print()

print(f"Trend Line Equation: Sales = {z[0]:.2f} × Ad_Spend + {z[1]:.2f}")
print(f"Slope: {z[0]:.2f} (For every $1 increase in ad spend, sales increase by ${z[0]:.2f})")
print(f"Intercept: ${z[1]:.2f}")
print()

roi = (z[0] - 1) * 100
print(f"Return on Investment (ROI): {roi:.1f}%")
print()

print("=" * 70)
print("CHART INTERPRETATION")
print("=" * 70)
print()

print("1. Relationship Pattern:")
if correlation > 0.7:
    print("   - Strong positive correlation between ad spend and sales")
elif correlation > 0.4:
    print("   - Moderate positive correlation between ad spend and sales")
else:
    print("   - Weak positive correlation between ad spend and sales")
print(f"   - Correlation coefficient: {correlation:.3f}")
print("   - Higher ad spend generally leads to higher sales")
print()

print("2. Trend Analysis:")
print("   - The red trend line shows the overall pattern")
print("   - Data points cluster around the trend line")
print("   - Some variation exists due to other factors")
print("   - Overall upward trend is clearly visible")
print()

print("3. Business Insights:")
print(f"   - Every $1,000 spent on ads generates ~${z[0]*1000:.2f} in sales")
print(f"   - ROI of {roi:.1f}% indicates profitable advertising")
print("   - Consistent pattern across different spending levels")
print()

print("=" * 70)
print("RECOMMENDATIONS FOR MARKETING STRATEGY")
print("=" * 70)
print()

print("1. Budget Allocation:")
print("   - Increase ad spend for higher revenue potential")
print("   - Current ROI justifies continued investment")
print("   - Consider scaling up successful campaigns")
print()

print("2. Optimization Opportunities:")
print("   - Analyze outliers (points far from trend line)")
print("   - Identify what makes high-performing campaigns successful")
print("   - Replicate strategies from campaigns above the trend line")
print("   - Investigate underperforming campaigns below the line")
print()

print("3. Risk Management:")
print("   - Diversify ad channels to reduce risk")
print("   - Test different spending levels systematically")
print("   - Monitor ROI continuously for changes")
print("   - Set maximum spend limits based on diminishing returns")
print()

print("4. Future Actions:")
print("   - Collect more data on campaign types and channels")
print("   - Track seasonal variations in effectiveness")
print("   - A/B test different ad creatives and messaging")
print("   - Consider non-linear models for better predictions")
print()

low_spend_avg = np.mean(sales_revenue[ad_spend < 10000])
high_spend_avg = np.mean(sales_revenue[ad_spend >= 10000])
print("Performance Comparison:")
print(f"   - Low Spend (<$10k): Average Sales = ${low_spend_avg:.2f}")
print(f"   - High Spend (≥$10k): Average Sales = ${high_spend_avg:.2f}")
print(f"   - Difference: ${high_spend_avg - low_spend_avg:.2f}")
print()

print("Chart saved as 'ad_spend_sales_scatter.png'")
# Out:
# ...
# ADVERTISING SPEND VS SALES REVENUE ANALYSIS
# ...
#
# Dataset Statistics:
# Total Campaigns: 50
# Ad Spend Range: $2329.35 - $17518.56
# Average Ad Spend: $9134.78
# Sales Revenue Range: $3632.42 - $50778.64
# Average Sales Revenue: $22822.23
#
# Correlation Coefficient: 0.926
# ...
# TREND LINE ANALYSIS
# ...
#
# Trend Line Equation: Sales = 2.43 × Ad_Spend + 623.09
# Slope: 2.43 (For every $1 increase in ad spend, sales increase by $2.43)
# Intercept: $623.09
#
# Return on Investment (ROI): 143.0%
#
# ...
# CHART INTERPRETATION
# ...
#
# 1. Relationship Pattern:
#    - Strong positive correlation between ad spend and sales
#    - Correlation coefficient: 0.926
#    - Higher ad spend generally leads to higher sales
#
# 2. Trend Analysis:
#    - The red trend line shows the overall pattern
#    - Data points cluster around the trend line
#    - Some variation exists due to other factors
#    - Overall upward trend is clearly visible
#
# 3. Business Insights:
# ...

# %%
import random

heads = 0
total = 1000

for i in range(total):
  result = random.randint(0,1)
  if result == 1:
    heads += 1

tails = total - heads

print(f"Heads: {heads}")
print(f"Tails: {tails}")
print(f"Probability of Heads: {heads/total}")
print(f"Probability of Tails: {tails/total}")
# Out:
# Heads: 520
# Tails: 480
# Probability of Heads: 0.52
# Probability of Tails: 0.48

# %%
import numpy  as np
import matplotlib.pyplot as plt

heights = np.random.normal(165,8,200)

print("Shortest:" , round(heights.min(),1))
print("Tallest:" , round(heights.max(),1))
print("Mean:" , round(heights.mean(),1))
# Draw the bell shape
plt.hist(heights, bins=20, color='#00BFA6', edgecolor='white')

plt.axvline(heights.mean(), color='red', linestyle='--', label='Average')

plt.title("Distribution of Heights")
plt.xlabel("Height (cm)")
plt.ylabel("Frequency")
plt.legend()
plt.show()
# Out:
# Shortest: 142.2
# Tallest: 182.3
# Mean: 166.0

# %%
from scipy .stats import binom
n = 10
p = 0.25

p3 = binom.pmf(3,n,p)
print("P(exactly 3) =", round(p3 , 3) )
# Answer : about 0.25 = 25%

# P(at least 5 correct)?
p5 = 1-binom.cdf(4,n,p)
print("P(5 or more) = " , round(p5 , 3))
# Answer : about 0.08 = 8%


p7 = 1-binom.cdf(7,n,p)
print("P(7 or more) = " , round(p7 , 3))


# Draw the chart
import matplotlib.pyplot as plt
import numpy as np
# Out:
# P(exactly 3) = 0.25
# P(5 or more) =  0.078
# P(7 or more) =  0.0

# %%
from
